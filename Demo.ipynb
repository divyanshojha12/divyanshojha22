# %% [markdown]
# <a href="https://colab.research.google.com/github/divyanshojha12/divyanshojha22/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello ")
# Out:
# Hello

# %%
name = "Divyansh Ojha"
age = 20
college_name = "SRMCEM"
print (name)
print (age)
print (college_name)
# Out:
# Divyansh Ojha
# 20
# SRMCEM

# %%
a,b=12,21
print (a,b)

print (b,a)
# Out:
# 12 21
# 21 12

# %%
a=1.837
print (int (a))
# Out:
# 1

# %%
a=input("enter your name")
b=input("enter your college name")
c=input("enter your department name")
d=int(input("enter your age"))
print(d)
print(a)
print(b)
print(c)
# Out:
# enter your nameDivyansh
# enter your college nameSRMCEM
# enter your department nameCS
# enter your age20
# 20
# Divyansh
# SRMCEM
# CS

# %%
age = int(input("enter your age"))
if (age >= 21 and age <= 60):
  print ("you are eligible to be a member of a parliament")
else :
    print ("you are not eligible to be a member of a parliament")
# Out:
# enter your age37
# you are eligible to be a member of a parliament

# %%
marks = int(input("Enter your marks: "))
if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
# Out:
# Enter your marks: 83
# Grade B

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# Enter a number: 37
# The number is odd.

# %%
thoughts= "have faith in god"
print (thoughts)
# Out:
# have faith in god

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=int(input("enter a number"))
operator = input("+,-,*,/,%")
if (operator == '+'):
  print(a+b+c)
elif (operator == '-'):
  print(a-b-c)
elif (operator == '*'):
  print(a*b*c)
elif (operator == '/'):
  print(a/b)
elif (operator == '%'):
  print(a%c)
else :
  print ("None of the above")
# Out:
# enter a number37
# enter a number67
# enter a number69
# +,-,*,/,%%
# 37

# %%
for i in range (10,1,-1):
 print (i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
a=(input("enter a number "))
c=(str((len(a))))
print("No. has " + c + " digit")
# Out:
# enter a number 123456789900987654321
# No. has 21 digit

# %%
for i in range (5,51,5):
  print (i)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
for i in range(1,11):
 sum = 37 *i
 print ("37 * " + str(i) + " = " + str(sum))
# Out:
# 37 * 1 = 37
# 37 * 2 = 74
# 37 * 3 = 111
# 37 * 4 = 148
# 37 * 5 = 185
# 37 * 6 = 222
# 37 * 7 = 259
# 37 * 8 = 296
# 37 * 9 = 333
# 37 * 10 = 370

# %%
import pandas as pd

# Creating a DataFrame from a Dictionary
data = {
    'Roll_No': [101, 102, 103, 104, 105],
    'Name': ['Utkarsh', 'Aditya', 'Gyanharshit', 'Divyansh', 'Eshan'],
    'Branch': ['CSE', 'ECE', 'CSE', 'ME', 'EE'],
    'CGPA': [8.5, 9.2, 7.8, 8.8, 6.5],
    'Placed': ['Yes', 'Yes', 'No', 'Yes', 'No']
}

df = pd.DataFrame(data)

# Inspecting the data
print("--- First 3 rows of the DataFrame ---")
print(df.head(3))

print("\n--- Summary Information ---")
print(df.info())  # Evaluates data types and missing values

print("\n--- Statistical Summary (Numerical Columns) ---")
print(df.describe())
# Out:
# --- First 3 rows of the DataFrame ---
#    Roll_No         Name Branch  CGPA Placed
# 0      101      Utkarsh    CSE   8.5    Yes
# 1      102       Aditya    ECE   9.2    Yes
# 2      103  Gyanharshit    CSE   7.8     No
#
# --- Summary Information ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll_No  5 non-null      int64
#  1   Name     5 non-null      object
#  2   Branch   5 non-null      object
#  3   CGPA     5 non-null      float64
#  4   Placed   5 non-null      object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 332.0+ bytes
# None
#
# --- Statistical Summary (Numerical Columns) ---
#           Roll_No      CGPA
# count    5.000000  5.000000
# mean   103.000000  8.160000
# std      1.581139  1.059717
# min    101.000000  6.500000
# 25%    102.000000  7.800000
# 50%    103.000000  8.500000
# ...

# %%
# Filtering: Extracting all students belonging to the CSE branch
cse_students = df[df['Branch'] == 'CSE']
print("--- CSE Students ---")
print(cse_students)
# Out:
# --- CSE Students ---
#    Roll_No         Name Branch  CGPA Placed
# 0      101      Utkarsh    CSE   8.5    Yes
# 2      103  Gyanharshit    CSE   7.8     No

# %%
# Multi-condition filtering: Students with CGPA > 8.0 AND Placed == 'Yes'
high_achievers = df[(df['CGPA'] > 8.0) & (df['Placed'] == 'Yes')]
print("\n--- High Achievers Placed ---")
print(high_achievers)
# Out:
# --- High Achievers Placed ---
#    Roll_No      Name Branch  CGPA Placed
# 0      101   Utkarsh    CSE   8.5    Yes
# 1      102    Aditya    ECE   9.2    Yes
# 3      104  Divyansh     ME   8.8    Yes

# %%
import numpy as np

# Injecting a row with a missing value for demonstration purposes
df.loc[5] = [106, 'Faizan', 'CSE', np.nan, 'No']

# 1. Handling Missing Values: Imputing missing CGPA with the column mean
mean_cgpa = df['CGPA'].mean()
df['CGPA'] = df['CGPA'].fillna(mean_cgpa)

# 2. Creating a calculated column: Converting CGPA to an approximate percentage
df['Percentage'] = df['CGPA'] * 9.5

print("--- Modified and Cleaned DataFrame ---")
print(df)
# Out:
# --- Modified and Cleaned DataFrame ---
#    Roll_No         Name Branch  CGPA Placed  Percentage
# 0      101      Utkarsh    CSE  8.50    Yes       80.75
# 1      102       Aditya    ECE  9.20    Yes       87.40
# 2      103  Gyanharshit    CSE  7.80     No       74.10
# 3      104     Divyansh     ME  8.80    Yes       83.60
# 4      105        Eshan     EE  6.50     No       61.75
# 5      106       Faizan    CSE  8.16     No       77.52

# %%
# Grouping by 'Branch' and computing the mean CGPA for each cluster
branch_perf = df.groupby('Branch')['CGPA'].mean().reset_index()
print("--- Average CGPA by Branch ---")
print(branch_perf)

# Multi-level Grouping: Counting placements partitioned across different branches
placement_counts = df.groupby(['Branch', 'Placed']).size().unstack(fill_value=0)
print("\n--- Placement Count Matrix ---")
print(placement_counts)
# Out:
# --- Average CGPA by Branch ---
#   Branch      CGPA
# 0    CSE  8.153333
# 1    ECE  9.200000
# 2     EE  6.500000
# 3     ME  8.800000
#
# --- Placement Count Matrix ---
# Placed  No  Yes
# Branch
# CSE      2    1
# ECE      0    1
# EE       1    0
# ME       0    1
