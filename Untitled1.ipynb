# %% [markdown]
# <a href="https://colab.research.google.com/github/divyanshojha12/divyanshojha22/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello ")
# Out:
# Hello

# %%
name = "Divyansh Ojha"
age = 20
college_name = "SRMCEM"
print (name)
print (age)
print (college_name)
# Out:
# Divyansh Ojha
# 20
# SRMCEM

# %%
a,b=12,21
print (a,b)

print (b,a)
# Out:
# 12 21
# 21 12

# %%
a=1.837
print (int (a))
# Out:
# 1

# %%
a=input("enter your name")
b=input("enter your college name")
c=input("enter your department name")
d=int(input("enter your age"))
print(d)
print(a)
print(b)
print(c)
# Out:
# enter your nameDivyansh
# enter your college nameSRMCEM
# enter your department nameCS
# enter your age20
# 20
# Divyansh
# SRMCEM
# CS

# %%
age = int(input("enter your age"))
if (age >= 21 and age <= 60):
  print ("you are eligible to be a member of a parliament")
else :
    print ("you are not eligible to be a member of a parliament")
# Out:
# enter your age37
# you are eligible to be a member of a parliament

# %%
marks = int(input("Enter your marks: "))
if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
# Out:
# Enter your marks: 83
# Grade B

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
# Out:
# Enter a number: 37
# The number is odd.

# %%
thoughts= "have faith in god"
print (thoughts)
# Out:
# have faith in god

# %%
a=int(input("enter a number"))
b=int(input("enter a number"))
c=int(input("enter a number"))
operator = input("+,-,*,/,%")
if (operator == '+'):
  print(a+b+c)
elif (operator == '-'):
  print(a-b-c)
elif (operator == '*'):
  print(a*b*c)
elif (operator == '/'):
  print(a/b)
elif (operator == '%'):
  print(a%c)
else :
  print ("None of the above")
# Out:
# enter a number37
# enter a number67
# enter a number69
# +,-,*,/,%%
# 37

# %%
for i in range (10,1,-1):
 print (i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
a=(input("enter a number "))
c=(str((len(a))))
print("No. has " + c + " digit")
# Out:
# enter a number 123456789900987654321
# No. has 21 digit

# %%
for i in range (5,51,5):
  print (i)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
for i in range(1,11):
 sum = 37 *i
 print ("37 * " + str(i) + " = " + str(sum))
# Out:
# 37 * 1 = 37
# 37 * 2 = 74
# 37 * 3 = 111
# 37 * 4 = 148
# 37 * 5 = 185
# 37 * 6 = 222
# 37 * 7 = 259
# 37 * 8 = 296
# 37 * 9 = 333
# 37 * 10 = 370
